# %%
using Plots

# %%
pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
const points = rand(4,4)
# Out:
# 4×4 Array{Float64,2}:
#  0.339683  0.753781  0.8703    0.333982
#  0.842142  0.525966  0.215019  0.233259
#  0.153369  0.705217  0.654468  0.70653
#  0.178186  0.390978  0.957911  0.940646

# %%
plot(points)
# Out:
# PyPlot.Figure(PyObject <Figure size 600x400 with 1 Axes>)
